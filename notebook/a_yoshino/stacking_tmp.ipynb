# %% [markdown]
# スタッキング

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, StratifiedKFold, GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve
import lightgbm as lgb

os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# /Users/a_yoshino/anaconda3/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_9.4.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
origin_train = pd.read_csv("../input/train.csv")

# %%
lg_tra = pd.read_csv("./Logistic_train_predict.csv").drop(["Unnamed: 0"], axis=1)
lg_tes = pd.read_csv("./Logistic_test_predict.csv").drop(["Unnamed: 0"], axis=1)
# lgbm_tra = pd.read_csv("./LGBM_train_submmit.csv")
# lgbm_tes = pd.read_csv("./LGBM_test_submmit.csv")
# niv_tra = pd.read_csv("./naive_bayes_train_submission.csv")
# niv_tes = pd.read_csv("./naive_bayes_test_submission.csv")
lgsvm_tra = pd.read_csv("./train_5x-LinearSVC-01-v1-oof_0859008_2019-03-29-16-30.csv")
lgsvm_tes = pd.read_csv("./submission_5x-LinearSVC-01-v1_0859008_2019-03-29-16-30.csv")

# %%
train_list = [lgbm_tra, niv_tra, lgsvm_tra["prediction"]]
test_list =[lgbm_tes, niv_tes, lgsvm_tes]
columns_list =["lgbm", "niv", "lgsvm"]

train_data = pd.DataFrame([])
test_data = pd.DataFrame([])

for li in train_list:
     train_data = pd.concat([train_data, li], axis=1)

for li in test_list:
     test_data = pd.concat([test_data, li], axis=1)

train_data = train_data.drop(["ID_code"], axis=1)
train_data.columns = columns_list
test_data = test_data.drop(["ID_code"], axis=1)
test_data.columns = columns_list

# %%
param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.4,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.05,
    'learning_rate': 0.01,
    'max_depth': 2,  
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': 1
}
# param = {
#     'bagging_freq': 8, #handling overfitting
#     'bagging_fraction': 0.4, #handling overfitting - adding some noise
#     'boost_from_average':'false',
#     'boost': 'gbdt',
#     'feature_fraction': 0.4, #handling overfitting
#     'learning_rate': 0.01, #the changes between one auc and a better one gets really small thus a small learning rate performs better
#     'max_depth': 2,  #smaller trees less overfitting
#     'metric':'auc',
#     'num_threads': 8,
#     'tree_learner': 'serial',
#     'objective': 'binary', 
#     'verbosity': 0
#     }

features= train_data.columns
train = train_data
test = test_data
target = origin_train.target

# %%
folds = StratifiedKFold(n_splits=10, shuffle=False, random_state=44000)
oof = np.zeros(len(train))
predictions = np.zeros(len(test))
feature_importance = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    print("Fold {}".format(fold_))
    #argument
#     trn_train, trn_target= augment(np.array(train.iloc[trn_idx]), np.array(np.array(target.iloc[trn_idx])))
#     trn_data = lgb.Dataset(trn_train, label=trn_target)
#     val_train, val_target= augment(np.array(train.iloc[val_idx]), np.array(target.iloc[val_idx]))
#     val_data = lgb.Dataset(val_train, label=val_target)

    #not argument
    trn_data = lgb.Dataset(train.iloc[trn_idx], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train.iloc[val_idx], label=target.iloc[val_idx])
    
    num_round = 30000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 3000)
    oof[val_idx] = clf.predict(train.iloc[val_idx], num_iteration=clf.best_iteration)
    
    fold_importance = pd.DataFrame()
    fold_importance["Feature"] = features
    fold_importance["importance"] = clf.feature_importance()
    fold_importance["fold"] = fold_ + 1
    feature_importance = pd.concat([feature_importance, fold_importance], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
# Out:
# Fold 0
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.915471	valid_1's auc: 0.913606
# [2000]	training's auc: 0.922082	valid_1's auc: 0.92042
# [3000]	training's auc: 0.923982	valid_1's auc: 0.922628
# [4000]	training's auc: 0.92447	valid_1's auc: 0.923132
# [5000]	training's auc: 0.924689	valid_1's auc: 0.923184
# [6000]	training's auc: 0.924805	valid_1's auc: 0.923134
# [7000]	training's auc: 0.924891	valid_1's auc: 0.923042
# [8000]	training's auc: 0.924976	valid_1's auc: 0.92298
# Early stopping, best iteration is:
# [5175]	training's auc: 0.924711	valid_1's auc: 0.923209
# Fold 1
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.915521	valid_1's auc: 0.913475
# [2000]	training's auc: 0.922062	valid_1's auc: 0.920115
# [3000]	training's auc: 0.92403	valid_1's auc: 0.922056
# [4000]	training's auc: 0.924529	valid_1's auc: 0.92243
# [5000]	training's auc: 0.924746	valid_1's auc: 0.922385
# [6000]	training's auc: 0.924858	valid_1's auc: 0.922397
# [7000]	training's auc: 0.924956	valid_1's auc: 0.922337
# Early stopping, best iteration is:
# [4598]	training's auc: 0.924672	valid_1's auc: 0.922491
# Fold 2
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.916057	valid_1's auc: 0.910897
# [2000]	training's auc: 0.922756	valid_1's auc: 0.916339
# [3000]	training's auc: 0.924624	valid_1's auc: 0.917541
# [4000]	training's auc: 0.925135	valid_1's auc: 0.917627
# [5000]	training's auc: 0.92533	valid_1's auc: 0.917549
# [6000]	training's auc: 0.925456	valid_1's auc: 0.917474
# Early stopping, best iteration is:
# [3804]	training's auc: 0.92507	valid_1's auc: 0.917666
# Fold 3
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.915448	valid_1's auc: 0.913316
# [2000]	training's auc: 0.922018	valid_1's auc: 0.92061
# [3000]	training's auc: 0.923952	valid_1's auc: 0.922531
# [4000]	training's auc: 0.924467	valid_1's auc: 0.923033
# [5000]	training's auc: 0.924663	valid_1's auc: 0.923121
# [6000]	training's auc: 0.92479	valid_1's auc: 0.923121
# [7000]	training's auc: 0.924866	valid_1's auc: 0.923103
# [8000]	training's auc: 0.924944	valid_1's auc: 0.923087
# Early stopping, best iteration is:
# [5306]	training's auc: 0.924708	valid_1's auc: 0.923149
# Fold 4
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.915532	valid_1's auc: 0.913228
# [2000]	training's auc: 0.922064	valid_1's auc: 0.920787
# [3000]	training's auc: 0.923898	valid_1's auc: 0.923242
# [4000]	training's auc: 0.924395	valid_1's auc: 0.923876
# [5000]	training's auc: 0.924586	valid_1's auc: 0.92408
# [6000]	training's auc: 0.924705	valid_1's auc: 0.924098
# [7000]	training's auc: 0.924789	valid_1's auc: 0.924153
# [8000]	training's auc: 0.924861	valid_1's auc: 0.924144
# [9000]	training's auc: 0.924938	valid_1's auc: 0.924092
# Early stopping, best iteration is:
# [6891]	training's auc: 0.924779	valid_1's auc: 0.924164
# Fold 5
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.915163	valid_1's auc: 0.916636
# [2000]	training's auc: 0.921776	valid_1's auc: 0.923438
# [3000]	training's auc: 0.923712	valid_1's auc: 0.925348
# [4000]	training's auc: 0.924229	valid_1's auc: 0.925697
# [5000]	training's auc: 0.924417	valid_1's auc: 0.925727
# [6000]	training's auc: 0.924552	valid_1's auc: 0.925658
# [7000]	training's auc: 0.924625	valid_1's auc: 0.925531
# Early stopping, best iteration is:
# [4541]	training's auc: 0.924344	valid_1's auc: 0.925759
# Fold 6
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.915351	valid_1's auc: 0.915222
# [2000]	training's auc: 0.922067	valid_1's auc: 0.921563
# [3000]	training's auc: 0.923949	valid_1's auc: 0.923314
# [4000]	training's auc: 0.92447	valid_1's auc: 0.92362
# [5000]	training's auc: 0.924679	valid_1's auc: 0.923618
# [6000]	training's auc: 0.924807	valid_1's auc: 0.923518
# [7000]	training's auc: 0.924898	valid_1's auc: 0.923454
# Early stopping, best iteration is:
# [4322]	training's auc: 0.924562	valid_1's auc: 0.923655
# Fold 7
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.915305	valid_1's auc: 0.916183
# [2000]	training's auc: 0.9221	valid_1's auc: 0.921757
# [3000]	training's auc: 0.924035	valid_1's auc: 0.922679
# [4000]	training's auc: 0.924553	valid_1's auc: 0.92271
# [5000]	training's auc: 0.924744	valid_1's auc: 0.922574
# [6000]	training's auc: 0.924854	valid_1's auc: 0.922484
# Early stopping, best iteration is:
# [3505]	training's auc: 0.924383	valid_1's auc: 0.922758
# Fold 8
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.914826	valid_1's auc: 0.919486
# [2000]	training's auc: 0.921503	valid_1's auc: 0.92563
# [3000]	training's auc: 0.923418	valid_1's auc: 0.92741
# [4000]	training's auc: 0.923925	valid_1's auc: 0.927685
# [5000]	training's auc: 0.924119	valid_1's auc: 0.927757
# [6000]	training's auc: 0.924249	valid_1's auc: 0.927688
# [7000]	training's auc: 0.924321	valid_1's auc: 0.9276
# Early stopping, best iteration is:
# [4622]	training's auc: 0.924055	valid_1's auc: 0.92779
# Fold 9
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.915297	valid_1's auc: 0.916156
# [2000]	training's auc: 0.922007	valid_1's auc: 0.921782
# [3000]	training's auc: 0.923973	valid_1's auc: 0.922893
# [4000]	training's auc: 0.924485	valid_1's auc: 0.923063
# [5000]	training's auc: 0.924689	valid_1's auc: 0.923014
# [6000]	training's auc: 0.924814	valid_1's auc: 0.922918
# Early stopping, best iteration is:
# [3941]	training's auc: 0.924468	valid_1's auc: 0.923072
# CV score: 0.92328

# %%
score = round(roc_auc_score(target, oof), 4)
sub = pd.DataFrame({"ID_code": lg_tes["ID_code"]})
sub["target"]=predictions
sub.to_csv(f"../output/submission_ensemble_stacking_{score}.csv", index=False)
