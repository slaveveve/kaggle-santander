# %%
import os
import time
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import log_loss, roc_auc_score, roc_curve
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.utils.fixes import logsumexp

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
TRAIN_DATA_PATH = './train.csv'
TEST_DATA_PATH = './test.csv'

origin_train = pd.read_csv(TRAIN_DATA_PATH)
origin_test = pd.read_csv(TEST_DATA_PATH)
features = origin_train.columns[2:]
target = pd.DataFrame(origin_train, columns=['target'])
df_train = pd.DataFrame(origin_train, columns=features)
df_test = pd.DataFrame(origin_test, columns=features)

# %%
# kernel引用
params = {
    'boosting':'gbdt', 
    'bagging_freq':5,
    'bagging_fraction':0.5,
    'num_leaves':2,
    'reg_lambda':100.0,
    'learning_rate':0.01, 
    'max_bin':1023,
    'seed':3366
}

# %%
def optimal_rounds(X, verbose=False):
    """
    各機能に対してnfoldで指定した数分のCVでLGBMを早期に停止しながら実行し、各機能に最適なツリー数を決定します。
    """
    rounds = []
    for i in range(len(df_train.columns)):
        if verbose:
            print("Feature ", i)
        cv_res = lgb.cv(params, 
           lgb.Dataset(df_train[['var_'+str(i)]], target.iloc[:, 0]),
           nfold=3, # 速度向上のために小さな値にしておく
           num_boost_round=100000,
           metrics='binary_logloss',
           verbose_eval=100 if verbose else None,
           early_stopping_rounds=100
          )
        rounds.append(len(cv_res['binary_logloss-mean']))
    return rounds

opt_rounds = optimal_rounds(df_train, verbose=True)
# Out:
# Feature  0
# [100]	cv_agg's binary_logloss: 0.324643 + 0.000112501
# [200]	cv_agg's binary_logloss: 0.324307 + 0.000144592
# [300]	cv_agg's binary_logloss: 0.324229 + 0.000148846
# [400]	cv_agg's binary_logloss: 0.324217 + 0.000153991
# Feature  1
# [100]	cv_agg's binary_logloss: 0.324862 + 2.69714e-05
# [200]	cv_agg's binary_logloss: 0.324486 + 2.77672e-05
# [300]	cv_agg's binary_logloss: 0.324365 + 2.0729e-05
# [400]	cv_agg's binary_logloss: 0.324333 + 1.02923e-05
# [500]	cv_agg's binary_logloss: 0.324326 + 4.91504e-06
# [600]	cv_agg's binary_logloss: 0.32433 + 4.53892e-06
# Feature  2
# [100]	cv_agg's binary_logloss: 0.324606 + 0.000195444
# [200]	cv_agg's binary_logloss: 0.324209 + 0.000286782
# [300]	cv_agg's binary_logloss: 0.324101 + 0.000346028
# [400]	cv_agg's binary_logloss: 0.324083 + 0.00037177
# [500]	cv_agg's binary_logloss: 0.324085 + 0.00038213
# [600]	cv_agg's binary_logloss: 0.324082 + 0.000382774
# Feature  3
# [100]	cv_agg's binary_logloss: 0.326073 + 3.99854e-05
# [200]	cv_agg's binary_logloss: 0.326047 + 6.03031e-05
# [300]	cv_agg's binary_logloss: 0.326042 + 7.70979e-05
# [400]	cv_agg's binary_logloss: 0.326046 + 7.22589e-05
# Feature  4
# [100]	cv_agg's binary_logloss: 0.32606 + 3.54344e-05
# [200]	cv_agg's binary_logloss: 0.326055 + 4.29899e-05
# Feature  5
# [100]	cv_agg's binary_logloss: 0.325461 + 4.09461e-05
# [200]	cv_agg's binary_logloss: 0.325319 + 3.97384e-05
# [300]	cv_agg's binary_logloss: 0.325273 + 4.40662e-05
# [400]	cv_agg's binary_logloss: 0.325267 + 4.6476e-05
# Feature  6
# [100]	cv_agg's binary_logloss: 0.324111 + 8.75152e-05
# [200]	cv_agg's binary_logloss: 0.323586 + 0.000113372
# [300]	cv_agg's binary_logloss: 0.323438 + 0.000119662
# [400]	cv_agg's binary_logloss: 0.323399 + 0.000124667
# [500]	cv_agg's binary_logloss: 0.323392 + 0.000125275
# [600]	cv_agg's binary_logloss: 0.323393 + 0.000123156
# Feature  7
# [100]	cv_agg's binary_logloss: 0.32617 + 1.03005e-05
# Feature  8
# [100]	cv_agg's binary_logloss: 0.325952 + 2.02447e-05
# [200]	cv_agg's binary_logloss: 0.325904 + 3.05959e-05
# [300]	cv_agg's binary_logloss: 0.325896 + 3.8145e-05
# [400]	cv_agg's binary_logloss: 0.3259 + 3.74693e-05
# Feature  9
# [100]	cv_agg's binary_logloss: 0.325097 + 0.000115514
# [200]	cv_agg's binary_logloss: 0.324783 + 0.000189266
# [300]	cv_agg's binary_logloss: 0.32467 + 0.000228783
# [400]	cv_agg's binary_logloss: 0.324635 + 0.000254495
# [500]	cv_agg's binary_logloss: 0.324615 + 0.000265705
# [600]	cv_agg's binary_logloss: 0.324606 + 0.000277698
# [700]	cv_agg's binary_logloss: 0.324593 + 0.000279719
# [800]	cv_agg's binary_logloss: 0.324581 + 0.000286288
# [900]	cv_agg's binary_logloss: 0.324577 + 0.000284658
# [1000]	cv_agg's binary_logloss: 0.324572 + 0.000281044
# [1100]	cv_agg's binary_logloss: 0.324566 + 0.00028735
# [1200]	cv_agg's binary_logloss: 0.324565 + 0.000283034
# Feature  10
# [100]	cv_agg's binary_logloss: 0.326144 + 1.41561e-05
# [200]	cv_agg's binary_logloss: 0.326144 + 1.4229e-05
# [300]	cv_agg's binary_logloss: 0.326146 + 1.16598e-05
# Feature  11
# [100]	cv_agg's binary_logloss: 0.325944 + 1.00608e-05
# [200]	cv_agg's binary_logloss: 0.325898 + 2.2637e-05
# [300]	cv_agg's binary_logloss: 0.325889 + 3.15812e-05
# Feature  12
# [100]	cv_agg's binary_logloss: 0.323514 + 5.00923e-05
# [200]	cv_agg's binary_logloss: 0.322907 + 4.35624e-05
# [300]	cv_agg's binary_logloss: 0.322721 + 2.96975e-05
# [400]	cv_agg's binary_logloss: 0.322676 + 2.87192e-05
# [500]	cv_agg's binary_logloss: 0.322662 + 2.48963e-05
# [600]	cv_agg's binary_logloss: 0.322663 + 2.40148e-05
# [700]	cv_agg's binary_logloss: 0.322663 + 2.67906e-05
# Feature  13
# [100]	cv_agg's binary_logloss: 0.324661 + 5.51746e-05
# [200]	cv_agg's binary_logloss: 0.324224 + 8.38852e-05
# [300]	cv_agg's binary_logloss: 0.324084 + 0.000112741
# [400]	cv_agg's binary_logloss: 0.324045 + 0.000132861
# [500]	cv_agg's binary_logloss: 0.32404 + 0.000136359
# Feature  14
# [100]	cv_agg's binary_logloss: 0.32614 + 1.24891e-05
# [200]	cv_agg's binary_logloss: 0.32614 + 1.15475e-05
# Feature  15
# [100]	cv_agg's binary_logloss: 0.326001 + 3.17442e-06
# [200]	cv_agg's binary_logloss: 0.325961 + 1.99952e-05
# [300]	cv_agg's binary_logloss: 0.325961 + 2.17324e-05
# Feature  16
# [100]	cv_agg's binary_logloss: 0.326084 + 9.17382e-06
# [200]	cv_agg's binary_logloss: 0.326081 + 1.21955e-05
# [300]	cv_agg's binary_logloss: 0.326084 + 1.59013e-05
# Feature  17
# [100]	cv_agg's binary_logloss: 0.326173 + 2.25597e-05
# Feature  18
# [100]	cv_agg's binary_logloss: 0.325193 + 5.97637e-05
# [200]	cv_agg's binary_logloss: 0.324927 + 9.70839e-05
# [300]	cv_agg's binary_logloss: 0.32484 + 0.000114402
# [400]	cv_agg's binary_logloss: 0.324823 + 0.000123147
# [500]	cv_agg's binary_logloss: 0.324826 + 0.000135104
# Feature  19
# [100]	cv_agg's binary_logloss: 0.326071 + 1.08806e-05
# [200]	cv_agg's binary_logloss: 0.326059 + 1.60169e-05
# [300]	cv_agg's binary_logloss: 0.326056 + 2.13437e-05
# [400]	cv_agg's binary_logloss: 0.32605 + 2.28666e-05
# [500]	cv_agg's binary_logloss: 0.326051 + 2.04034e-05
# Feature  20
# [100]	cv_agg's binary_logloss: 0.325943 + 2.86408e-05
# [200]	cv_agg's binary_logloss: 0.325884 + 4.43173e-05
# [300]	cv_agg's binary_logloss: 0.325861 + 5.68647e-05
# [400]	cv_agg's binary_logloss: 0.325852 + 5.62565e-05
# [500]	cv_agg's binary_logloss: 0.325847 + 5.38327e-05
# [600]	cv_agg's binary_logloss: 0.325844 + 5.21937e-05
# [700]	cv_agg's binary_logloss: 0.325847 + 5.77247e-05
# Feature  21
# [100]	cv_agg's binary_logloss: 0.32455 + 2.77445e-05
# [200]	cv_agg's binary_logloss: 0.324119 + 4.06696e-05
# [300]	cv_agg's binary_logloss: 0.324008 + 5.46159e-05
# [400]	cv_agg's binary_logloss: 0.323981 + 6.74574e-05
# [500]	cv_agg's binary_logloss: 0.323976 + 7.28103e-05
# [600]	cv_agg's binary_logloss: 0.323972 + 7.05704e-05
# [700]	cv_agg's binary_logloss: 0.323963 + 7.21352e-05
# [800]	cv_agg's binary_logloss: 0.323964 + 7.22666e-05
# [900]	cv_agg's binary_logloss: 0.323965 + 7.43976e-05
# Feature  22
# [100]	cv_agg's binary_logloss: 0.324341 + 7.73684e-05
# [200]	cv_agg's binary_logloss: 0.323864 + 0.000126387
# [300]	cv_agg's binary_logloss: 0.323723 + 0.000151647
# [400]	cv_agg's binary_logloss: 0.323691 + 0.000168975
# [500]	cv_agg's binary_logloss: 0.32368 + 0.000185202
# [600]	cv_agg's binary_logloss: 0.32368 + 0.00018143
# Feature  23
# [100]	cv_agg's binary_logloss: 0.325857 + 5.77483e-05
# [200]	cv_agg's binary_logloss: 0.325793 + 7.56927e-05
# [300]	cv_agg's binary_logloss: 0.325771 + 8.22514e-05
# [400]	cv_agg's binary_logloss: 0.32577 + 8.76743e-05
# Feature  24
# [100]	cv_agg's binary_logloss: 0.325765 + 4.7004e-05
# [200]	cv_agg's binary_logloss: 0.325648 + 6.45627e-05
# [300]	cv_agg's binary_logloss: 0.325617 + 7.15979e-05
# [400]	cv_agg's binary_logloss: 0.325613 + 8.10198e-05
# [500]	cv_agg's binary_logloss: 0.325612 + 9.19134e-05
# Feature  25
# [100]	cv_agg's binary_logloss: 0.326079 + 2.85248e-05
# [200]	cv_agg's binary_logloss: 0.326068 + 4.01e-05
# [300]	cv_agg's binary_logloss: 0.326072 + 4.85224e-05
# Feature  26
# [100]	cv_agg's binary_logloss: 0.323951 + 3.62909e-05
# [200]	cv_agg's binary_logloss: 0.323506 + 8.14435e-05
# [300]	cv_agg's binary_logloss: 0.323392 + 0.000114226
# [400]	cv_agg's binary_logloss: 0.323368 + 0.000123762
# [500]	cv_agg's binary_logloss: 0.323368 + 0.000130989
# Feature  27
# [100]	cv_agg's binary_logloss: 0.326167 + 2.48057e-05
# Feature  28
# [100]	cv_agg's binary_logloss: 0.325867 + 3.45715e-05
# [200]	cv_agg's binary_logloss: 0.3258 + 5.11124e-05
# [300]	cv_agg's binary_logloss: 0.325793 + 5.12591e-05
# [400]	cv_agg's binary_logloss: 0.32579 + 5.32981e-05
# [500]	cv_agg's binary_logloss: 0.325799 + 5.51895e-05
# Feature  29
# [100]	cv_agg's binary_logloss: 0.32616 + 2.32921e-05
# Feature  30
# [100]	cv_agg's binary_logloss: 0.326171 + 1.68364e-05
# Feature  31
# [100]	cv_agg's binary_logloss: 0.325858 + 2.7275e-05
# [200]	cv_agg's binary_logloss: 0.325791 + 2.64466e-05
# [300]	cv_agg's binary_logloss: 0.325779 + 2.89818e-05
# [400]	cv_agg's binary_logloss: 0.325779 + 2.86341e-05
# [500]	cv_agg's binary_logloss: 0.32578 + 3.15463e-05
# Feature  32
# [100]	cv_agg's binary_logloss: 0.325629 + 4.52583e-05
# [200]	cv_agg's binary_logloss: 0.325499 + 6.7334e-05
# [300]	cv_agg's binary_logloss: 0.325451 + 7.25823e-05
# [400]	cv_agg's binary_logloss: 0.325442 + 8.25393e-05
# [500]	cv_agg's binary_logloss: 0.325443 + 8.47246e-05
# Feature  33
# [100]	cv_agg's binary_logloss: 0.324994 + 3.71399e-05
# [200]	cv_agg's binary_logloss: 0.324701 + 5.88292e-05
# [300]	cv_agg's binary_logloss: 0.324601 + 7.48758e-05
# [400]	cv_agg's binary_logloss: 0.324566 + 8.15704e-05
# [500]	cv_agg's binary_logloss: 0.324556 + 8.63678e-05
# [600]	cv_agg's binary_logloss: 0.324559 + 8.59729e-05
# Feature  34
# [100]	cv_agg's binary_logloss: 0.324929 + 0.000147007
# [200]	cv_agg's binary_logloss: 0.324571 + 0.000222958
# [300]	cv_agg's binary_logloss: 0.324445 + 0.000288139
# [400]	cv_agg's binary_logloss: 0.324409 + 0.000326085
# [500]	cv_agg's binary_logloss: 0.324402 + 0.000348806
# Feature  35
# [100]	cv_agg's binary_logloss: 0.325524 + 4.93463e-05
# [200]	cv_agg's binary_logloss: 0.325355 + 5.67514e-05
# [300]	cv_agg's binary_logloss: 0.325317 + 6.05311e-05
# [400]	cv_agg's binary_logloss: 0.325312 + 6.29939e-05
# [500]	cv_agg's binary_logloss: 0.325315 + 6.38107e-05
# Feature  36
# [100]	cv_agg's binary_logloss: 0.325487 + 3.73368e-05
# [200]	cv_agg's binary_logloss: 0.325303 + 7.49784e-05
# [300]	cv_agg's binary_logloss: 0.325257 + 8.96711e-05
# [400]	cv_agg's binary_logloss: 0.325248 + 0.000102165
# [500]	cv_agg's binary_logloss: 0.325242 + 0.000101197
# [600]	cv_agg's binary_logloss: 0.325245 + 0.000106308
# Feature  37
# [100]	cv_agg's binary_logloss: 0.32609 + 2.34007e-05
# [200]	cv_agg's binary_logloss: 0.326078 + 3.28762e-05
# [300]	cv_agg's binary_logloss: 0.326077 + 3.97804e-05
# Feature  38
# [100]	cv_agg's binary_logloss: 0.326165 + 1.42669e-05
# Feature  39
# [100]	cv_agg's binary_logloss: 0.326145 + 8.40598e-06
# [200]	cv_agg's binary_logloss: 0.326145 + 4.31384e-06
# Feature  40
# [100]	cv_agg's binary_logloss: 0.324823 + 0.000129946
# [200]	cv_agg's binary_logloss: 0.3245 + 0.000182534
# [300]	cv_agg's binary_logloss: 0.324394 + 0.000199662
# [400]	cv_agg's binary_logloss: 0.324372 + 0.000214243
# [500]	cv_agg's binary_logloss: 0.324367 + 0.000218403
# Feature  41
# [100]	cv_agg's binary_logloss: 0.326153 + 6.23263e-06
# Feature  42
# [100]	cv_agg's binary_logloss: 0.326136 + 1.94076e-06
# Feature  43
# [100]	cv_agg's binary_logloss: 0.325701 + 1.73113e-05
# [200]	cv_agg's binary_logloss: 0.325584 + 3.21496e-05
# [300]	cv_agg's binary_logloss: 0.325562 + 4.24905e-05
# [400]	cv_agg's binary_logloss: 0.325565 + 3.87891e-05
# Feature  44
# [100]	cv_agg's binary_logloss: 0.324622 + 4.61251e-06
# [200]	cv_agg's binary_logloss: 0.324364 + 2.78242e-05
# [300]	cv_agg's binary_logloss: 0.324317 + 3.6281e-05
# [400]	cv_agg's binary_logloss: 0.324314 + 4.1034e-05
# [500]	cv_agg's binary_logloss: 0.324316 + 4.40562e-05
# Feature  45
# [100]	cv_agg's binary_logloss: 0.325987 + 3.34891e-05
# [200]	cv_agg's binary_logloss: 0.325949 + 6.24339e-05
# [300]	cv_agg's binary_logloss: 0.325951 + 8.19969e-05
# Feature  46
# [100]	cv_agg's binary_logloss: 0.32615 + 1.62857e-05
# Feature  47
# [100]	cv_agg's binary_logloss: 0.326123 + 1.28067e-05
# [200]	cv_agg's binary_logloss: 0.326124 + 2.00754e-05
# Feature  48
# [100]	cv_agg's binary_logloss: 0.325745 + 1.75475e-05
# [200]	cv_agg's binary_logloss: 0.325619 + 2.85714e-05
# [300]	cv_agg's binary_logloss: 0.325593 + 2.9875e-05
# [400]	cv_agg's binary_logloss: 0.325596 + 3.74801e-05
# Feature  49
# [100]	cv_agg's binary_logloss: 0.325641 + 7.35302e-05
# [200]	cv_agg's binary_logloss: 0.325497 + 0.000112203
# [300]	cv_agg's binary_logloss: 0.325447 + 0.000133779
# [400]	cv_agg's binary_logloss: 0.325438 + 0.000149276
# [500]	cv_agg's binary_logloss: 0.325439 + 0.000156864
# Feature  50
# [100]	cv_agg's binary_logloss: 0.32603 + 1.71285e-05
# [200]	cv_agg's binary_logloss: 0.326011 + 1.90132e-05
# [300]	cv_agg's binary_logloss: 0.326015 + 1.76967e-05
# Feature  51
# [100]	cv_agg's binary_logloss: 0.325701 + 3.10404e-05
# [200]	cv_agg's binary_logloss: 0.325601 + 3.36321e-05
# [300]	cv_agg's binary_logloss: 0.325566 + 4.41889e-05
# [400]	cv_agg's binary_logloss: 0.325554 + 4.88169e-05
# [500]	cv_agg's binary_logloss: 0.325551 + 5.48552e-05
# [600]	cv_agg's binary_logloss: 0.325547 + 5.31593e-05
# [700]	cv_agg's binary_logloss: 0.325549 + 5.26757e-05
# Feature  52
# [100]	cv_agg's binary_logloss: 0.325776 + 5.13679e-05
# [200]	cv_agg's binary_logloss: 0.325693 + 8.35562e-05
# [300]	cv_agg's binary_logloss: 0.325685 + 9.77442e-05
# [400]	cv_agg's binary_logloss: 0.325684 + 0.000100145
# Feature  53
# [100]	cv_agg's binary_logloss: 0.323925 + 0.000119418
# [200]	cv_agg's binary_logloss: 0.323393 + 0.000157267
# [300]	cv_agg's binary_logloss: 0.323236 + 0.000161399
# [400]	cv_agg's binary_logloss: 0.323205 + 0.000162869
# [500]	cv_agg's binary_logloss: 0.323197 + 0.000159757
# [600]	cv_agg's binary_logloss: 0.323199 + 0.000160443
# Feature  54
# [100]	cv_agg's binary_logloss: 0.326035 + 4.19603e-05
# [200]	cv_agg's binary_logloss: 0.326007 + 5.60058e-05
# [300]	cv_agg's binary_logloss: 0.325998 + 7.21308e-05
# [400]	cv_agg's binary_logloss: 0.325997 + 7.89909e-05
# [500]	cv_agg's binary_logloss: 0.325991 + 8.18855e-05
# [600]	cv_agg's binary_logloss: 0.325989 + 8.78032e-05
# Feature  55
# [100]	cv_agg's binary_logloss: 0.326001 + 3.34682e-05
# [200]	cv_agg's binary_logloss: 0.325955 + 5.58941e-05
# [300]	cv_agg's binary_logloss: 0.32595 + 7.52145e-05
# [400]	cv_agg's binary_logloss: 0.325946 + 8.35743e-05
# [500]	cv_agg's binary_logloss: 0.325947 + 8.43625e-05
# Feature  56
# [100]	cv_agg's binary_logloss: 0.325483 + 4.778e-05
# [200]	cv_agg's binary_logloss: 0.325321 + 7.38824e-05
# [300]	cv_agg's binary_logloss: 0.325277 + 9.13311e-05
# [400]	cv_agg's binary_logloss: 0.325266 + 0.000107569
# [500]	cv_agg's binary_logloss: 0.32527 + 0.000113931
# Feature  57
# [100]	cv_agg's binary_logloss: 0.326058 + 1.43002e-05
# [200]	cv_agg's binary_logloss: 0.326037 + 2.82583e-05
# [300]	cv_agg's binary_logloss: 0.326035 + 3.68627e-05
# Feature  58
# [100]	cv_agg's binary_logloss: 0.325852 + 0.000101725
# [200]	cv_agg's binary_logloss: 0.325798 + 0.000146706
# [300]	cv_agg's binary_logloss: 0.325805 + 0.000169286
# Feature  59
# [100]	cv_agg's binary_logloss: 0.326102 + 1.8959e-05
# [200]	cv_agg's binary_logloss: 0.326097 + 2.2994e-05
# [300]	cv_agg's binary_logloss: 0.326096 + 2.81185e-05
# [400]	cv_agg's binary_logloss: 0.326093 + 3.10477e-05
# Feature  60
# [100]	cv_agg's binary_logloss: 0.326082 + 3.96006e-05
# [200]	cv_agg's binary_logloss: 0.326079 + 5.56999e-05
# Feature  61
# [100]	cv_agg's binary_logloss: 0.326122 + 1.75626e-05
# [200]	cv_agg's binary_logloss: 0.326117 + 2.83852e-05
# Feature  62
# [100]	cv_agg's binary_logloss: 0.326061 + 1.38504e-05
# [200]	cv_agg's binary_logloss: 0.326047 + 2.32176e-05
# [300]	cv_agg's binary_logloss: 0.32605 + 3.32995e-05
# Feature  63
# [100]	cv_agg's binary_logloss: 0.326048 + 6.74366e-06
# [200]	cv_agg's binary_logloss: 0.326021 + 2.05588e-05
# [300]	cv_agg's binary_logloss: 0.326016 + 2.76917e-05
# [400]	cv_agg's binary_logloss: 0.326016 + 2.81517e-05
# Feature  64
# [100]	cv_agg's binary_logloss: 0.32607 + 1.4585e-05
# [200]	cv_agg's binary_logloss: 0.32605 + 2.89763e-05
# [300]	cv_agg's binary_logloss: 0.326047 + 4.24955e-05
# Feature  65
# [100]	cv_agg's binary_logloss: 0.326115 + 2.94199e-05
# [200]	cv_agg's binary_logloss: 0.326116 + 5.17919e-05
# Feature  66
# [100]	cv_agg's binary_logloss: 0.325905 + 2.01718e-05
# [200]	cv_agg's binary_logloss: 0.325849 + 4.10513e-05
# [300]	cv_agg's binary_logloss: 0.325839 + 5.0567e-05
# [400]	cv_agg's binary_logloss: 0.325838 + 6.02179e-05
# Feature  67
# [100]	cv_agg's binary_logloss: 0.325285 + 0.000125149
# [200]	cv_agg's binary_logloss: 0.325064 + 0.000190156
# [300]	cv_agg's binary_logloss: 0.32501 + 0.000230412
# [400]	cv_agg's binary_logloss: 0.325007 + 0.000237497
# Feature  68
# [100]	cv_agg's binary_logloss: 0.326059 + 6.72131e-06
# [200]	cv_agg's binary_logloss: 0.326039 + 1.52458e-05
# [300]	cv_agg's binary_logloss: 0.326034 + 2.10805e-05
# Feature  69
# [100]	cv_agg's binary_logloss: 0.326053 + 1.39567e-05
# [200]	cv_agg's binary_logloss: 0.326038 + 1.68776e-05
# [300]	cv_agg's binary_logloss: 0.326036 + 1.49909e-05
# Feature  70
# [100]	cv_agg's binary_logloss: 0.325828 + 7.47243e-06
# [200]	cv_agg's binary_logloss: 0.325727 + 2.06111e-05
# [300]	cv_agg's binary_logloss: 0.325692 + 2.84882e-05
# [400]	cv_agg's binary_logloss: 0.325682 + 3.69079e-05
# [500]	cv_agg's binary_logloss: 0.325684 + 4.15161e-05
# Feature  71
# [100]	cv_agg's binary_logloss: 0.325719 + 9.92492e-06
# [200]	cv_agg's binary_logloss: 0.325584 + 2.83703e-05
# [300]	cv_agg's binary_logloss: 0.325552 + 3.91567e-05
# [400]	cv_agg's binary_logloss: 0.325545 + 4.29349e-05
# [500]	cv_agg's binary_logloss: 0.325542 + 4.82543e-05
# Feature  72
# [100]	cv_agg's binary_logloss: 0.326074 + 1.74353e-05
# [200]	cv_agg's binary_logloss: 0.326067 + 3.15197e-05
# Feature  73
# [100]	cv_agg's binary_logloss: 0.326148 + 2.03833e-05
# Feature  74
# [100]	cv_agg's binary_logloss: 0.325995 + 3.62701e-05
# [200]	cv_agg's binary_logloss: 0.325963 + 5.58662e-05
# [300]	cv_agg's binary_logloss: 0.325957 + 7.34272e-05
# [400]	cv_agg's binary_logloss: 0.325949 + 7.67247e-05
# [500]	cv_agg's binary_logloss: 0.325955 + 7.86765e-05
# Feature  75
# [100]	cv_agg's binary_logloss: 0.325353 + 0.000119429
# [200]	cv_agg's binary_logloss: 0.325148 + 0.000159836
# [300]	cv_agg's binary_logloss: 0.325089 + 0.000175418
# [400]	cv_agg's binary_logloss: 0.325079 + 0.0001753
# [500]	cv_agg's binary_logloss: 0.325078 + 0.000179119
# Feature  76
# [100]	cv_agg's binary_logloss: 0.324378 + 0.000212346
# [200]	cv_agg's binary_logloss: 0.323929 + 0.000323336
# [300]	cv_agg's binary_logloss: 0.323792 + 0.000378254
# [400]	cv_agg's binary_logloss: 0.323759 + 0.000412834
# [500]	cv_agg's binary_logloss: 0.32376 + 0.000433051
# Feature  77
# [100]	cv_agg's binary_logloss: 0.326006 + 3.76329e-05
# [200]	cv_agg's binary_logloss: 0.325967 + 5.8228e-05
# [300]	cv_agg's binary_logloss: 0.325967 + 6.00435e-05
# Feature  78
# [100]	cv_agg's binary_logloss: 0.324667 + 6.56623e-05
# [200]	cv_agg's binary_logloss: 0.324346 + 9.51436e-05
# [300]	cv_agg's binary_logloss: 0.324227 + 0.000128352
# [400]	cv_agg's binary_logloss: 0.324193 + 0.000146485
# [500]	cv_agg's binary_logloss: 0.324188 + 0.000158102
# Feature  79
# [100]	cv_agg's binary_logloss: 0.326118 + 2.6378e-05
# [200]	cv_agg's binary_logloss: 0.326118 + 3.24339e-05
# Feature  80
# [100]	cv_agg's binary_logloss: 0.324298 + 0.000170755
# [200]	cv_agg's binary_logloss: 0.323838 + 0.000278683
# [300]	cv_agg's binary_logloss: 0.323718 + 0.000339187
# [400]	cv_agg's binary_logloss: 0.323681 + 0.00037624
# [500]	cv_agg's binary_logloss: 0.323663 + 0.000396868
# [600]	cv_agg's binary_logloss: 0.323659 + 0.000396983
# [700]	cv_agg's binary_logloss: 0.323655 + 0.000401825
# [800]	cv_agg's binary_logloss: 0.323651 + 0.000411441
# [900]	cv_agg's binary_logloss: 0.323644 + 0.000413617
# [1000]	cv_agg's binary_logloss: 0.323646 + 0.000417432
# [1100]	cv_agg's binary_logloss: 0.323641 + 0.00042329
# Feature  81
# [100]	cv_agg's binary_logloss: 0.322328 + 9.34224e-05
# [200]	cv_agg's binary_logloss: 0.321617 + 0.000170548
# [300]	cv_agg's binary_logloss: 0.321453 + 0.000212825
# [400]	cv_agg's binary_logloss: 0.321426 + 0.000236124
# [500]	cv_agg's binary_logloss: 0.321422 + 0.000253855
# Feature  82
# [100]	cv_agg's binary_logloss: 0.325872 + 4.88223e-05
# [200]	cv_agg's binary_logloss: 0.32579 + 6.5696e-05
# [300]	cv_agg's binary_logloss: 0.325762 + 8.53966e-05
# [400]	cv_agg's binary_logloss: 0.325766 + 9.59731e-05
# Feature  83
# [100]	cv_agg's binary_logloss: 0.325877 + 8.42518e-05
# [200]	cv_agg's binary_logloss: 0.325825 + 0.000119723
# [300]	cv_agg's binary_logloss: 0.325824 + 0.000140463
# [400]	cv_agg's binary_logloss: 0.325823 + 0.000148902
# Feature  84
# [100]	cv_agg's binary_logloss: 0.326101 + 3.56669e-05
# [200]	cv_agg's binary_logloss: 0.326099 + 4.67762e-05
# Feature  85
# [100]	cv_agg's binary_logloss: 0.325819 + 1.39569e-05
# [200]	cv_agg's binary_logloss: 0.325712 + 1.7372e-05
# [300]	cv_agg's binary_logloss: 0.325687 + 2.66557e-05
# [400]	cv_agg's binary_logloss: 0.325684 + 3.21678e-05
# Feature  86
# [100]	cv_agg's binary_logloss: 0.325256 + 8.41731e-05
# [200]	cv_agg's binary_logloss: 0.32506 + 0.000144091
# [300]	cv_agg's binary_logloss: 0.325034 + 0.00017184
# [400]	cv_agg's binary_logloss: 0.325037 + 0.000182655
# Feature  87
# [100]	cv_agg's binary_logloss: 0.325574 + 9.12471e-06
# [200]	cv_agg's binary_logloss: 0.325395 + 6.91931e-06
# [300]	cv_agg's binary_logloss: 0.325338 + 1.88602e-05
# [400]	cv_agg's binary_logloss: 0.32532 + 3.01916e-05
# [500]	cv_agg's binary_logloss: 0.325308 + 3.54455e-05
# [600]	cv_agg's binary_logloss: 0.325309 + 5.05504e-05
# Feature  88
# [100]	cv_agg's binary_logloss: 0.325885 + 3.16413e-05
# [200]	cv_agg's binary_logloss: 0.325822 + 4.52621e-05
# [300]	cv_agg's binary_logloss: 0.325814 + 5.30451e-05
# Feature  89
# [100]	cv_agg's binary_logloss: 0.325368 + 8.68876e-05
# [200]	cv_agg's binary_logloss: 0.325203 + 0.000123834
# [300]	cv_agg's binary_logloss: 0.325161 + 0.000158004
# [400]	cv_agg's binary_logloss: 0.325159 + 0.000180254
# [500]	cv_agg's binary_logloss: 0.325162 + 0.000194108
# Feature  90
# [100]	cv_agg's binary_logloss: 0.325764 + 1.63683e-05
# [200]	cv_agg's binary_logloss: 0.325639 + 3.2794e-05
# [300]	cv_agg's binary_logloss: 0.325596 + 4.11065e-05
# [400]	cv_agg's binary_logloss: 0.325589 + 4.59283e-05
# Feature  91
# [100]	cv_agg's binary_logloss: 0.325323 + 7.07221e-05
# [200]	cv_agg's binary_logloss: 0.325098 + 0.000109402
# [300]	cv_agg's binary_logloss: 0.325023 + 0.000138179
# [400]	cv_agg's binary_logloss: 0.325009 + 0.000165163
# [500]	cv_agg's binary_logloss: 0.325005 + 0.000172873
# [600]	cv_agg's binary_logloss: 0.325005 + 0.000180411
# Feature  92
# [100]	cv_agg's binary_logloss: 0.324984 + 7.28439e-05
# [200]	cv_agg's binary_logloss: 0.324631 + 0.000136597
# [300]	cv_agg's binary_logloss: 0.324522 + 0.000158237
# [400]	cv_agg's binary_logloss: 0.324493 + 0.000175566
# [500]	cv_agg's binary_logloss: 0.324485 + 0.000184824
# [600]	cv_agg's binary_logloss: 0.324483 + 0.00019403
# Feature  93
# [100]	cv_agg's binary_logloss: 0.325493 + 3.97024e-05
# [200]	cv_agg's binary_logloss: 0.325356 + 6.07076e-05
# [300]	cv_agg's binary_logloss: 0.325332 + 6.37528e-05
# Feature  94
# [100]	cv_agg's binary_logloss: 0.324915 + 3.66986e-05
# [200]	cv_agg's binary_logloss: 0.324548 + 1.55763e-05
# [300]	cv_agg's binary_logloss: 0.324434 + 2.03006e-05
# [400]	cv_agg's binary_logloss: 0.324388 + 3.46886e-05
# [500]	cv_agg's binary_logloss: 0.324385 + 4.15402e-05
# [600]	cv_agg's binary_logloss: 0.324378 + 4.142e-05
# [700]	cv_agg's binary_logloss: 0.324372 + 4.56797e-05
# [800]	cv_agg's binary_logloss: 0.32437 + 4.67736e-05
# [900]	cv_agg's binary_logloss: 0.324369 + 4.69295e-05
# Feature  95
# [100]	cv_agg's binary_logloss: 0.325316 + 1.62971e-05
# [200]	cv_agg's binary_logloss: 0.325136 + 1.33915e-05
# [300]	cv_agg's binary_logloss: 0.325092 + 2.68783e-05
# [400]	cv_agg's binary_logloss: 0.325093 + 3.49253e-05
# Feature  96
# [100]	cv_agg's binary_logloss: 0.326155 + 1.79878e-05
# Feature  97
# [100]	cv_agg's binary_logloss: 0.326033 + 5.32867e-05
# [200]	cv_agg's binary_logloss: 0.326004 + 7.96768e-05
# [300]	cv_agg's binary_logloss: 0.326009 + 8.63619e-05
# Feature  98
# [100]	cv_agg's binary_logloss: 0.326146 + 1.72364e-05
# [200]	cv_agg's binary_logloss: 0.326153 + 2.26259e-05
# Feature  99
# [100]	cv_agg's binary_logloss: 0.324449 + 7.51831e-05
# [200]	cv_agg's binary_logloss: 0.323997 + 0.000146522
# [300]	cv_agg's binary_logloss: 0.323876 + 0.000182599
# [400]	cv_agg's binary_logloss: 0.32385 + 0.000199274
# [500]	cv_agg's binary_logloss: 0.323849 + 0.000215186
# Feature  100
# [100]	cv_agg's binary_logloss: 0.326154 + 1.42086e-05
# [200]	cv_agg's binary_logloss: 0.326153 + 1.62254e-05
# Feature  101
# [100]	cv_agg's binary_logloss: 0.326114 + 2.08976e-05
# [200]	cv_agg's binary_logloss: 0.326099 + 2.82377e-05
# [300]	cv_agg's binary_logloss: 0.326096 + 3.94806e-05
# [400]	cv_agg's binary_logloss: 0.326096 + 4.11179e-05
# Feature  102
# [100]	cv_agg's binary_logloss: 0.32597 + 5.99502e-05
# [200]	cv_agg's binary_logloss: 0.325946 + 9.83608e-05
# Feature  103
# [100]	cv_agg's binary_logloss: 0.326168 + 8.56488e-06
# Feature  104
# [100]	cv_agg's binary_logloss: 0.325871 + 1.65292e-05
# [200]	cv_agg's binary_logloss: 0.325808 + 3.50375e-05
# [300]	cv_agg's binary_logloss: 0.325796 + 4.41744e-05
# [400]	cv_agg's binary_logloss: 0.325793 + 4.9363e-05
# [500]	cv_agg's binary_logloss: 0.325791 + 4.92613e-05
# [600]	cv_agg's binary_logloss: 0.325786 + 5.02046e-05
# [700]	cv_agg's binary_logloss: 0.325781 + 5.03391e-05
# [800]	cv_agg's binary_logloss: 0.325786 + 5.8424e-05
# Feature  105
# [100]	cv_agg's binary_logloss: 0.325826 + 2.26014e-05
# [200]	cv_agg's binary_logloss: 0.325781 + 3.86801e-05
# [300]	cv_agg's binary_logloss: 0.32578 + 4.60475e-05
# Feature  106
# [100]	cv_agg's binary_logloss: 0.325607 + 2.31061e-05
# [200]	cv_agg's binary_logloss: 0.32547 + 2.25887e-05
# [300]	cv_agg's binary_logloss: 0.325443 + 3.02987e-05
# [400]	cv_agg's binary_logloss: 0.325441 + 3.15128e-05
# Feature  107
# [100]	cv_agg's binary_logloss: 0.325383 + 5.82549e-05
# [200]	cv_agg's binary_logloss: 0.325173 + 6.35585e-05
# [300]	cv_agg's binary_logloss: 0.325129 + 8.59129e-05
# [400]	cv_agg's binary_logloss: 0.325113 + 9.54684e-05
# [500]	cv_agg's binary_logloss: 0.32511 + 0.000103063
# Feature  108
# [100]	cv_agg's binary_logloss: 0.324951 + 0.000146132
# [200]	cv_agg's binary_logloss: 0.324635 + 0.000215419
# [300]	cv_agg's binary_logloss: 0.32455 + 0.000269065
# [400]	cv_agg's binary_logloss: 0.324525 + 0.000288067
# [500]	cv_agg's binary_logloss: 0.324499 + 0.000295374
# [600]	cv_agg's binary_logloss: 0.324479 + 0.00029644
# [700]	cv_agg's binary_logloss: 0.324458 + 0.000298991
# [800]	cv_agg's binary_logloss: 0.324442 + 0.000304442
# [900]	cv_agg's binary_logloss: 0.324426 + 0.000301638
# [1000]	cv_agg's binary_logloss: 0.32441 + 0.000305259
# [1100]	cv_agg's binary_logloss: 0.324396 + 0.000303168
# [1200]	cv_agg's binary_logloss: 0.324379 + 0.000311744
# [1300]	cv_agg's binary_logloss: 0.324367 + 0.000308984
# [1400]	cv_agg's binary_logloss: 0.324354 + 0.000313344
# [1500]	cv_agg's binary_logloss: 0.324338 + 0.000321845
# [1600]	cv_agg's binary_logloss: 0.324339 + 0.000322183
# [1700]	cv_agg's binary_logloss: 0.324331 + 0.000320061
# [1800]	cv_agg's binary_logloss: 0.32432 + 0.000321822
# [1900]	cv_agg's binary_logloss: 0.324311 + 0.000329258
# [2000]	cv_agg's binary_logloss: 0.324309 + 0.000329093
# [2100]	cv_agg's binary_logloss: 0.324299 + 0.000332452
# [2200]	cv_agg's binary_logloss: 0.324292 + 0.000336102
# [2300]	cv_agg's binary_logloss: 0.324286 + 0.000334924
# [2400]	cv_agg's binary_logloss: 0.324277 + 0.000345323
# [2500]	cv_agg's binary_logloss: 0.324276 + 0.000340771
# Feature  109
# [100]	cv_agg's binary_logloss: 0.324292 + 6.75098e-05
# [200]	cv_agg's binary_logloss: 0.32394 + 0.000126674
# [300]	cv_agg's binary_logloss: 0.32383 + 0.000126017
# [400]	cv_agg's binary_logloss: 0.323794 + 0.000128876
# [500]	cv_agg's binary_logloss: 0.323791 + 0.000127267
# Feature  110
# [100]	cv_agg's binary_logloss: 0.323845 + 8.63146e-05
# [200]	cv_agg's binary_logloss: 0.323367 + 0.000126683
# [300]	cv_agg's binary_logloss: 0.323241 + 0.000156814
# [400]	cv_agg's binary_logloss: 0.323214 + 0.000167372
# [500]	cv_agg's binary_logloss: 0.323212 + 0.00017299
# Feature  111
# [100]	cv_agg's binary_logloss: 0.325711 + 3.84067e-05
# [200]	cv_agg's binary_logloss: 0.32561 + 4.69852e-05
# [300]	cv_agg's binary_logloss: 0.32559 + 4.81683e-05
# [400]	cv_agg's binary_logloss: 0.325588 + 4.8127e-05
# Feature  112
# [100]	cv_agg's binary_logloss: 0.325743 + 7.65062e-06
# [200]	cv_agg's binary_logloss: 0.325653 + 2.18898e-05
# [300]	cv_agg's binary_logloss: 0.325616 + 1.53436e-05
# [400]	cv_agg's binary_logloss: 0.325598 + 1.86211e-05
# [500]	cv_agg's binary_logloss: 0.325581 + 2.01761e-05
# [600]	cv_agg's binary_logloss: 0.325576 + 1.89735e-05
# [700]	cv_agg's binary_logloss: 0.325575 + 2.00872e-05
# Feature  113
# [100]	cv_agg's binary_logloss: 0.326057 + 2.38895e-05
# [200]	cv_agg's binary_logloss: 0.32604 + 2.94534e-05
# [300]	cv_agg's binary_logloss: 0.326041 + 3.23146e-05
# Feature  114
# [100]	cv_agg's binary_logloss: 0.325776 + 3.72287e-05
# [200]	cv_agg's binary_logloss: 0.325682 + 4.87738e-05
# [300]	cv_agg's binary_logloss: 0.325659 + 6.11082e-05
# [400]	cv_agg's binary_logloss: 0.325658 + 6.27016e-05
# Feature  115
# [100]	cv_agg's binary_logloss: 0.325085 + 8.6985e-05
# [200]	cv_agg's binary_logloss: 0.32477 + 0.000165973
# [300]	cv_agg's binary_logloss: 0.32468 + 0.000203028
# [400]	cv_agg's binary_logloss: 0.32467 + 0.000224591
# [500]	cv_agg's binary_logloss: 0.324674 + 0.000231483
# Feature  116
# [100]	cv_agg's binary_logloss: 0.325904 + 6.84637e-05
# [200]	cv_agg's binary_logloss: 0.32584 + 0.000120326
# [300]	cv_agg's binary_logloss: 0.325829 + 0.000157248
# Feature  117
# [100]	cv_agg's binary_logloss: 0.326154 + 5.1126e-06
# Feature  118
# [100]	cv_agg's binary_logloss: 0.325433 + 7.87707e-05
# [200]	cv_agg's binary_logloss: 0.325227 + 0.000138957
# [300]	cv_agg's binary_logloss: 0.325168 + 0.000174313
# [400]	cv_agg's binary_logloss: 0.325152 + 0.000197351
# [500]	cv_agg's binary_logloss: 0.325146 + 0.000210869
# [600]	cv_agg's binary_logloss: 0.325141 + 0.00021658
# [700]	cv_agg's binary_logloss: 0.325141 + 0.000223535
# [800]	cv_agg's binary_logloss: 0.325142 + 0.000228174
# Feature  119
# [100]	cv_agg's binary_logloss: 0.325566 + 1.09278e-05
# [200]	cv_agg's binary_logloss: 0.325419 + 1.69046e-05
# [300]	cv_agg's binary_logloss: 0.325387 + 2.04204e-05
# [400]	cv_agg's binary_logloss: 0.325372 + 2.06892e-05
# [500]	cv_agg's binary_logloss: 0.325381 + 2.67986e-05
# Feature  120
# [100]	cv_agg's binary_logloss: 0.326104 + 2.42986e-05
# [200]	cv_agg's binary_logloss: 0.326098 + 3.36563e-05
# Feature  121
# [100]	cv_agg's binary_logloss: 0.32522 + 4.19617e-05
# [200]	cv_agg's binary_logloss: 0.324979 + 6.85403e-05
# [300]	cv_agg's binary_logloss: 0.324898 + 9.01867e-05
# [400]	cv_agg's binary_logloss: 0.324879 + 0.00010533
# [500]	cv_agg's binary_logloss: 0.324879 + 0.000104155
# Feature  122
# [100]	cv_agg's binary_logloss: 0.325327 + 4.31505e-05
# [200]	cv_agg's binary_logloss: 0.325074 + 5.00271e-05
# [300]	cv_agg's binary_logloss: 0.325002 + 6.48146e-05
# [400]	cv_agg's binary_logloss: 0.324993 + 6.41407e-05
# [500]	cv_agg's binary_logloss: 0.324999 + 6.46685e-05
# Feature  123
# [100]	cv_agg's binary_logloss: 0.325206 + 5.65599e-05
# [200]	cv_agg's binary_logloss: 0.324966 + 9.5491e-05
# [300]	cv_agg's binary_logloss: 0.324909 + 0.000107141
# [400]	cv_agg's binary_logloss: 0.324902 + 0.000124479
# [500]	cv_agg's binary_logloss: 0.324906 + 0.000130889
# Feature  124
# [100]	cv_agg's binary_logloss: 0.326152 + 1.25615e-05
# [200]	cv_agg's binary_logloss: 0.32615 + 1.41066e-05
# [300]	cv_agg's binary_logloss: 0.326152 + 1.18642e-05
# Feature  125
# [100]	cv_agg's binary_logloss: 0.325719 + 1.03349e-05
# [200]	cv_agg's binary_logloss: 0.325623 + 3.83569e-05
# [300]	cv_agg's binary_logloss: 0.325593 + 4.60495e-05
# [400]	cv_agg's binary_logloss: 0.325595 + 4.79073e-05
# Feature  126
# [100]	cv_agg's binary_logloss: 0.326158 + 1.80716e-05
# Feature  127
# [100]	cv_agg's binary_logloss: 0.325391 + 9.5833e-05
# [200]	cv_agg's binary_logloss: 0.325145 + 0.000154951
# [300]	cv_agg's binary_logloss: 0.325064 + 0.000192046
# [400]	cv_agg's binary_logloss: 0.325048 + 0.000214155
# [500]	cv_agg's binary_logloss: 0.325039 + 0.000215786
# [600]	cv_agg's binary_logloss: 0.325036 + 0.000217855
# [700]	cv_agg's binary_logloss: 0.325033 + 0.000214909
# [800]	cv_agg's binary_logloss: 0.32503 + 0.000216092
# [900]	cv_agg's binary_logloss: 0.325031 + 0.000215851
# Feature  128
# [100]	cv_agg's binary_logloss: 0.325792 + 6.40842e-05
# [200]	cv_agg's binary_logloss: 0.325692 + 9.13601e-05
# [300]	cv_agg's binary_logloss: 0.325659 + 0.000112991
# [400]	cv_agg's binary_logloss: 0.325655 + 0.000121297
# [500]	cv_agg's binary_logloss: 0.325653 + 0.000129728
# [600]	cv_agg's binary_logloss: 0.325654 + 0.000133912
# Feature  129
# [100]	cv_agg's binary_logloss: 0.32613 + 1.5653e-05
# [200]	cv_agg's binary_logloss: 0.326128 + 2.09849e-05
# Feature  130
# [100]	cv_agg's binary_logloss: 0.325546 + 4.37764e-05
# [200]	cv_agg's binary_logloss: 0.325415 + 3.77381e-05
# [300]	cv_agg's binary_logloss: 0.32537 + 1.94912e-05
# [400]	cv_agg's binary_logloss: 0.325363 + 1.14318e-05
# [500]	cv_agg's binary_logloss: 0.32536 + 1.00817e-05
# [600]	cv_agg's binary_logloss: 0.325364 + 7.11222e-06
# Feature  131
# [100]	cv_agg's binary_logloss: 0.325678 + 5.65056e-05
# [200]	cv_agg's binary_logloss: 0.32553 + 9.3393e-05
# [300]	cv_agg's binary_logloss: 0.325487 + 0.000124118
# [400]	cv_agg's binary_logloss: 0.325477 + 0.000135735
# [500]	cv_agg's binary_logloss: 0.325478 + 0.000150681
# Feature  132
# [100]	cv_agg's binary_logloss: 0.325833 + 0.000112057
# [200]	cv_agg's binary_logloss: 0.32576 + 0.000177427
# [300]	cv_agg's binary_logloss: 0.325749 + 0.00020603
# [400]	cv_agg's binary_logloss: 0.325755 + 0.000227098
# Feature  133
# [100]	cv_agg's binary_logloss: 0.324631 + 0.000168135
# [200]	cv_agg's binary_logloss: 0.324276 + 0.000225206
# [300]	cv_agg's binary_logloss: 0.324171 + 0.000248779
# [400]	cv_agg's binary_logloss: 0.324136 + 0.000247277
# [500]	cv_agg's binary_logloss: 0.324133 + 0.000247156
# Feature  134
# [100]	cv_agg's binary_logloss: 0.325898 + 4.73115e-05
# [200]	cv_agg's binary_logloss: 0.325844 + 7.02506e-05
# [300]	cv_agg's binary_logloss: 0.325834 + 8.59875e-05
# [400]	cv_agg's binary_logloss: 0.325833 + 8.75522e-05
# [500]	cv_agg's binary_logloss: 0.325833 + 9.36257e-05
# Feature  135
# [100]	cv_agg's binary_logloss: 0.325695 + 2.35647e-05
# [200]	cv_agg's binary_logloss: 0.325596 + 3.68463e-05
# [300]	cv_agg's binary_logloss: 0.325577 + 4.84727e-05
# [400]	cv_agg's binary_logloss: 0.325577 + 5.44976e-05
# [500]	cv_agg's binary_logloss: 0.325577 + 5.67448e-05
# Feature  136
# [100]	cv_agg's binary_logloss: 0.326167 + 6.60263e-06
# Feature  137
# [100]	cv_agg's binary_logloss: 0.325774 + 3.06495e-05
# [200]	cv_agg's binary_logloss: 0.325657 + 4.26428e-05
# [300]	cv_agg's binary_logloss: 0.325625 + 5.30656e-05
# [400]	cv_agg's binary_logloss: 0.325615 + 5.89196e-05
# Feature  138
# [100]	cv_agg's binary_logloss: 0.326021 + 2.21142e-05
# [200]	cv_agg's binary_logloss: 0.325988 + 2.19091e-05
# [300]	cv_agg's binary_logloss: 0.325985 + 2.77773e-05
# [400]	cv_agg's binary_logloss: 0.32599 + 2.71157e-05
# Feature  139
# [100]	cv_agg's binary_logloss: 0.323215 + 0.00015098
# [200]	cv_agg's binary_logloss: 0.322556 + 0.000209618
# [300]	cv_agg's binary_logloss: 0.322392 + 0.000250519
# [400]	cv_agg's binary_logloss: 0.322352 + 0.00026105
# [500]	cv_agg's binary_logloss: 0.322346 + 0.000275327
# [600]	cv_agg's binary_logloss: 0.322341 + 0.000276347
# [700]	cv_agg's binary_logloss: 0.322339 + 0.000276
# [800]	cv_agg's binary_logloss: 0.322343 + 0.00027633
# Feature  140
# [100]	cv_agg's binary_logloss: 0.32608 + 2.89465e-05
# [200]	cv_agg's binary_logloss: 0.326061 + 4.70935e-05
# [300]	cv_agg's binary_logloss: 0.326066 + 5.44233e-05
# Feature  141
# [100]	cv_agg's binary_logloss: 0.325641 + 6.943e-05
# [200]	cv_agg's binary_logloss: 0.325483 + 8.92889e-05
# [300]	cv_agg's binary_logloss: 0.325438 + 0.000109572
# [400]	cv_agg's binary_logloss: 0.325425 + 0.00011507
# [500]	cv_agg's binary_logloss: 0.325424 + 0.000122363
# Feature  142
# [100]	cv_agg's binary_logloss: 0.326006 + 2.21801e-05
# [200]	cv_agg's binary_logloss: 0.325962 + 3.29288e-05
# [300]	cv_agg's binary_logloss: 0.325959 + 3.41406e-05
# Feature  143
# [100]	cv_agg's binary_logloss: 0.326068 + 1.29152e-05
# [200]	cv_agg's binary_logloss: 0.326056 + 1.3914e-05
# [300]	cv_agg's binary_logloss: 0.326058 + 1.80033e-05
# Feature  144
# [100]	cv_agg's binary_logloss: 0.325942 + 9.39223e-06
# [200]	cv_agg's binary_logloss: 0.325891 + 9.6743e-06
# [300]	cv_agg's binary_logloss: 0.325872 + 1.4695e-05
# [400]	cv_agg's binary_logloss: 0.325871 + 1.29756e-05
# Feature  145
# [100]	cv_agg's binary_logloss: 0.32563 + 2.10381e-05
# [200]	cv_agg's binary_logloss: 0.325506 + 2.65978e-05
# [300]	cv_agg's binary_logloss: 0.32546 + 4.04931e-05
# [400]	cv_agg's binary_logloss: 0.325452 + 4.45364e-05
# Feature  146
# [100]	cv_agg's binary_logloss: 0.324155 + 0.000144384
# [200]	cv_agg's binary_logloss: 0.32367 + 0.000233151
# [300]	cv_agg's binary_logloss: 0.323537 + 0.000267282
# [400]	cv_agg's binary_logloss: 0.323495 + 0.00029601
# [500]	cv_agg's binary_logloss: 0.323486 + 0.00030555
# Feature  147
# [100]	cv_agg's binary_logloss: 0.325343 + 8.14758e-05
# [200]	cv_agg's binary_logloss: 0.325126 + 0.000129984
# [300]	cv_agg's binary_logloss: 0.325063 + 0.000147636
# [400]	cv_agg's binary_logloss: 0.325049 + 0.000164417
# [500]	cv_agg's binary_logloss: 0.325047 + 0.000179663
# [600]	cv_agg's binary_logloss: 0.325051 + 0.000185904
# Feature  148
# [100]	cv_agg's binary_logloss: 0.324552 + 4.74331e-05
# [200]	cv_agg's binary_logloss: 0.324178 + 4.96328e-05
# [300]	cv_agg's binary_logloss: 0.324079 + 5.15214e-05
# [400]	cv_agg's binary_logloss: 0.324059 + 5.12581e-05
# [500]	cv_agg's binary_logloss: 0.324061 + 5.07501e-05
# [600]	cv_agg's binary_logloss: 0.324058 + 5.06441e-05
# [700]	cv_agg's binary_logloss: 0.324057 + 5.17458e-05
# Feature  149
# [100]	cv_agg's binary_logloss: 0.32521 + 9.75195e-05
# [200]	cv_agg's binary_logloss: 0.324963 + 0.000161905
# [300]	cv_agg's binary_logloss: 0.324902 + 0.000196707
# [400]	cv_agg's binary_logloss: 0.324889 + 0.00022006
# [500]	cv_agg's binary_logloss: 0.324885 + 0.000227951
# [600]	cv_agg's binary_logloss: 0.324878 + 0.000233903
# Feature  150
# [100]	cv_agg's binary_logloss: 0.325739 + 4.79112e-05
# [200]	cv_agg's binary_logloss: 0.325648 + 8.70075e-05
# [300]	cv_agg's binary_logloss: 0.325619 + 0.000105855
# [400]	cv_agg's binary_logloss: 0.325602 + 0.000117402
# [500]	cv_agg's binary_logloss: 0.325595 + 0.000122189
# [600]	cv_agg's binary_logloss: 0.325587 + 0.000125773
# [700]	cv_agg's binary_logloss: 0.325584 + 0.000130379
# [800]	cv_agg's binary_logloss: 0.325583 + 0.000128472
# Feature  151
# [100]	cv_agg's binary_logloss: 0.325709 + 1.74993e-05
# [200]	cv_agg's binary_logloss: 0.3256 + 1.69606e-05
# [300]	cv_agg's binary_logloss: 0.325573 + 1.95954e-05
# [400]	cv_agg's binary_logloss: 0.325565 + 1.82702e-05
# [500]	cv_agg's binary_logloss: 0.325565 + 1.47509e-05
# [600]	cv_agg's binary_logloss: 0.325562 + 9.41226e-06
# Feature  152
# [100]	cv_agg's binary_logloss: 0.326073 + 1.39816e-05
# [200]	cv_agg's binary_logloss: 0.326065 + 2.39588e-05
# Feature  153
# [100]	cv_agg's binary_logloss: 0.326128 + 2.07714e-05
# [200]	cv_agg's binary_logloss: 0.326145 + 2.51818e-05
# Feature  154
# [100]	cv_agg's binary_logloss: 0.325004 + 6.61325e-05
# [200]	cv_agg's binary_logloss: 0.324703 + 0.000118767
# [300]	cv_agg's binary_logloss: 0.324599 + 0.000143998
# [400]	cv_agg's binary_logloss: 0.32457 + 0.000166075
# [500]	cv_agg's binary_logloss: 0.324564 + 0.000172044
# Feature  155
# [100]	cv_agg's binary_logloss: 0.32543 + 2.6128e-05
# [200]	cv_agg's binary_logloss: 0.325268 + 6.99114e-05
# [300]	cv_agg's binary_logloss: 0.325238 + 0.000102606
# [400]	cv_agg's binary_logloss: 0.325248 + 0.000116277
# Feature  156
# [100]	cv_agg's binary_logloss: 0.32593 + 1.9953e-05
# [200]	cv_agg's binary_logloss: 0.325873 + 3.57584e-05
# [300]	cv_agg's binary_logloss: 0.325856 + 4.99332e-05
# [400]	cv_agg's binary_logloss: 0.32586 + 5.43561e-05
# Feature  157
# [100]	cv_agg's binary_logloss: 0.325569 + 0.000102549
# [200]	cv_agg's binary_logloss: 0.325441 + 0.000148612
# [300]	cv_agg's binary_logloss: 0.325423 + 0.000162123
# Feature  158
# [100]	cv_agg's binary_logloss: 0.326155 + 1.09348e-05
# Feature  159
# [100]	cv_agg's binary_logloss: 0.326056 + 1.95935e-05
# [200]	cv_agg's binary_logloss: 0.326047 + 2.3361e-05
# [300]	cv_agg's binary_logloss: 0.326049 + 1.78885e-05
# Feature  160
# [100]	cv_agg's binary_logloss: 0.326135 + 1.5259e-05
# [200]	cv_agg's binary_logloss: 0.326135 + 2.96708e-05
# Feature  161
# [100]	cv_agg's binary_logloss: 0.326151 + 1.98553e-05
# [200]	cv_agg's binary_logloss: 0.326152 + 2.92638e-05
# Feature  162
# [100]	cv_agg's binary_logloss: 0.325624 + 0.000111902
# [200]	cv_agg's binary_logloss: 0.325487 + 0.00017178
# [300]	cv_agg's binary_logloss: 0.325449 + 0.000201778
# [400]	cv_agg's binary_logloss: 0.32544 + 0.000216899
# Feature  163
# [100]	cv_agg's binary_logloss: 0.32555 + 7.25105e-05
# [200]	cv_agg's binary_logloss: 0.325393 + 0.00011734
# [300]	cv_agg's binary_logloss: 0.325377 + 0.000148022
# [400]	cv_agg's binary_logloss: 0.325374 + 0.000162425
# Feature  164
# [100]	cv_agg's binary_logloss: 0.324778 + 6.518e-05
# [200]	cv_agg's binary_logloss: 0.324462 + 5.42766e-05
# [300]	cv_agg's binary_logloss: 0.324368 + 4.65682e-05
# [400]	cv_agg's binary_logloss: 0.324338 + 4.15053e-05
# [500]	cv_agg's binary_logloss: 0.324336 + 3.78112e-05
# Feature  165
# [100]	cv_agg's binary_logloss: 0.324604 + 0.000111004
# [200]	cv_agg's binary_logloss: 0.324196 + 0.000135067
# [300]	cv_agg's binary_logloss: 0.324067 + 0.000162477
# [400]	cv_agg's binary_logloss: 0.32402 + 0.000183688
# [500]	cv_agg's binary_logloss: 0.324007 + 0.000195689
# [600]	cv_agg's binary_logloss: 0.324004 + 0.000201636
# Feature  166
# [100]	cv_agg's binary_logloss: 0.324326 + 8.55359e-05
# [200]	cv_agg's binary_logloss: 0.323863 + 0.000134256
# [300]	cv_agg's binary_logloss: 0.323707 + 0.00016056
# [400]	cv_agg's binary_logloss: 0.323658 + 0.000177474
# [500]	cv_agg's binary_logloss: 0.323653 + 0.000187533
# [600]	cv_agg's binary_logloss: 0.323653 + 0.00019269
# Feature  167
# [100]	cv_agg's binary_logloss: 0.325626 + 4.70431e-05
# [200]	cv_agg's binary_logloss: 0.325525 + 7.40091e-05
# [300]	cv_agg's binary_logloss: 0.325498 + 9.82299e-05
# [400]	cv_agg's binary_logloss: 0.325491 + 0.000100236
# [500]	cv_agg's binary_logloss: 0.325495 + 0.000103205
# Feature  168
# [100]	cv_agg's binary_logloss: 0.326011 + 2.97712e-05
# [200]	cv_agg's binary_logloss: 0.325992 + 5.0978e-05
# [300]	cv_agg's binary_logloss: 0.325988 + 6.41434e-05
# Feature  169
# [100]	cv_agg's binary_logloss: 0.325121 + 0.000209381
# [200]	cv_agg's binary_logloss: 0.324797 + 0.000284967
# [300]	cv_agg's binary_logloss: 0.324708 + 0.000353599
# [400]	cv_agg's binary_logloss: 0.324687 + 0.00037819
# [500]	cv_agg's binary_logloss: 0.324688 + 0.000395098
# Feature  170
# [100]	cv_agg's binary_logloss: 0.324923 + 4.21611e-05
# [200]	cv_agg's binary_logloss: 0.324641 + 4.2644e-05
# [300]	cv_agg's binary_logloss: 0.324569 + 4.83786e-05
# [400]	cv_agg's binary_logloss: 0.324542 + 5.10777e-05
# [500]	cv_agg's binary_logloss: 0.324542 + 5.67373e-05
# Feature  171
# [100]	cv_agg's binary_logloss: 0.326014 + 2.54703e-05
# [200]	cv_agg's binary_logloss: 0.326002 + 2.94004e-05
# [300]	cv_agg's binary_logloss: 0.326004 + 3.23597e-05
# Feature  172
# [100]	cv_agg's binary_logloss: 0.325447 + 1.79091e-05
# [200]	cv_agg's binary_logloss: 0.325273 + 3.23007e-05
# [300]	cv_agg's binary_logloss: 0.325232 + 3.66531e-05
# [400]	cv_agg's binary_logloss: 0.325226 + 3.43463e-05
# Feature  173
# [100]	cv_agg's binary_logloss: 0.325305 + 1.9028e-05
# [200]	cv_agg's binary_logloss: 0.325086 + 2.78414e-05
# [300]	cv_agg's binary_logloss: 0.325014 + 4.19165e-05
# [400]	cv_agg's binary_logloss: 0.324985 + 5.6023e-05
# [500]	cv_agg's binary_logloss: 0.324973 + 5.6597e-05
# [600]	cv_agg's binary_logloss: 0.324967 + 6.77441e-05
# [700]	cv_agg's binary_logloss: 0.324965 + 7.21732e-05
# Feature  174
# [100]	cv_agg's binary_logloss: 0.324184 + 4.14233e-05
# [200]	cv_agg's binary_logloss: 0.323684 + 5.17252e-05
# [300]	cv_agg's binary_logloss: 0.323527 + 6.59676e-05
# [400]	cv_agg's binary_logloss: 0.323485 + 6.93238e-05
# [500]	cv_agg's binary_logloss: 0.323475 + 7.79286e-05
# [600]	cv_agg's binary_logloss: 0.323476 + 8.7549e-05
# Feature  175
# [100]	cv_agg's binary_logloss: 0.32592 + 1.32098e-05
# [200]	cv_agg's binary_logloss: 0.325859 + 1.1005e-05
# [300]	cv_agg's binary_logloss: 0.325843 + 1.47063e-05
# [400]	cv_agg's binary_logloss: 0.325844 + 1.21938e-05
# Feature  176
# [100]	cv_agg's binary_logloss: 0.326132 + 3.27741e-05
# [200]	cv_agg's binary_logloss: 0.326137 + 5.18079e-05
# Feature  177
# [100]	cv_agg's binary_logloss: 0.324974 + 0.000103816
# [200]	cv_agg's binary_logloss: 0.324738 + 0.000131637
# [300]	cv_agg's binary_logloss: 0.324647 + 0.00012605
# [400]	cv_agg's binary_logloss: 0.324634 + 0.000134967
# [500]	cv_agg's binary_logloss: 0.324621 + 0.000140906
# [600]	cv_agg's binary_logloss: 0.324623 + 0.000144274
# Feature  178
# [100]	cv_agg's binary_logloss: 0.325966 + 1.61553e-05
# [200]	cv_agg's binary_logloss: 0.325927 + 3.12366e-05
# [300]	cv_agg's binary_logloss: 0.325921 + 3.29508e-05
# [400]	cv_agg's binary_logloss: 0.325922 + 3.26335e-05
# Feature  179
# [100]	cv_agg's binary_logloss: 0.324629 + 5.85116e-05
# [200]	cv_agg's binary_logloss: 0.324326 + 9.98907e-05
# [300]	cv_agg's binary_logloss: 0.324265 + 0.00013228
# [400]	cv_agg's binary_logloss: 0.324261 + 0.000143355
# Feature  180
# [100]	cv_agg's binary_logloss: 0.325518 + 6.09578e-05
# [200]	cv_agg's binary_logloss: 0.325371 + 9.04737e-05
# [300]	cv_agg's binary_logloss: 0.325326 + 0.000108797
# [400]	cv_agg's binary_logloss: 0.325319 + 0.00012216
# Feature  181
# [100]	cv_agg's binary_logloss: 0.326058 + 5.23898e-05
# [200]	cv_agg's binary_logloss: 0.32603 + 7.3268e-05
# [300]	cv_agg's binary_logloss: 0.32603 + 7.78378e-05
# Feature  182
# [100]	cv_agg's binary_logloss: 0.326158 + 1.62698e-05
# Feature  183
# [100]	cv_agg's binary_logloss: 0.326158 + 4.23437e-05
# Feature  184
# [100]	cv_agg's binary_logloss: 0.325079 + 0.000132799
# [200]	cv_agg's binary_logloss: 0.324761 + 0.000198023
# [300]	cv_agg's binary_logloss: 0.324653 + 0.000242382
# [400]	cv_agg's binary_logloss: 0.32462 + 0.000275158
# [500]	cv_agg's binary_logloss: 0.324616 + 0.000285196
# Feature  185
# [100]	cv_agg's binary_logloss: 0.32616 + 1.45257e-05
# Feature  186
# [100]	cv_agg's binary_logloss: 0.325708 + 7.41537e-05
# [200]	cv_agg's binary_logloss: 0.325607 + 0.000106384
# [300]	cv_agg's binary_logloss: 0.325571 + 0.000125234
# [400]	cv_agg's binary_logloss: 0.325553 + 0.000143429
# [500]	cv_agg's binary_logloss: 0.325548 + 0.000148641
# [600]	cv_agg's binary_logloss: 0.325547 + 0.000155886
# Feature  187
# [100]	cv_agg's binary_logloss: 0.326018 + 2.57567e-05
# [200]	cv_agg's binary_logloss: 0.325997 + 3.26213e-05
# [300]	cv_agg's binary_logloss: 0.325998 + 3.52479e-05
# Feature  188
# [100]	cv_agg's binary_logloss: 0.325385 + 7.37518e-05
# [200]	cv_agg's binary_logloss: 0.325216 + 0.000119635
# [300]	cv_agg's binary_logloss: 0.325171 + 0.000150412
# [400]	cv_agg's binary_logloss: 0.325166 + 0.000166255
# [500]	cv_agg's binary_logloss: 0.325164 + 0.000175043
# Feature  189
# [100]	cv_agg's binary_logloss: 0.326119 + 4.62554e-06
# [200]	cv_agg's binary_logloss: 0.326118 + 1.23743e-05
# Feature  190
# [100]	cv_agg's binary_logloss: 0.324636 + 3.74496e-05
# [200]	cv_agg's binary_logloss: 0.32425 + 5.01412e-05
# [300]	cv_agg's binary_logloss: 0.324135 + 6.38626e-05
# [400]	cv_agg's binary_logloss: 0.324103 + 6.42242e-05
# [500]	cv_agg's binary_logloss: 0.324095 + 6.65035e-05
# [600]	cv_agg's binary_logloss: 0.324093 + 5.91733e-05
# [700]	cv_agg's binary_logloss: 0.324095 + 5.66828e-05
# Feature  191
# [100]	cv_agg's binary_logloss: 0.325052 + 8.16186e-05
# [200]	cv_agg's binary_logloss: 0.324774 + 0.000122286
# [300]	cv_agg's binary_logloss: 0.324702 + 0.00014908
# [400]	cv_agg's binary_logloss: 0.324682 + 0.000161147
# [500]	cv_agg's binary_logloss: 0.324668 + 0.000175614
# [600]	cv_agg's binary_logloss: 0.324666 + 0.00017805
# Feature  192
# [100]	cv_agg's binary_logloss: 0.325326 + 3.46456e-05
# [200]	cv_agg's binary_logloss: 0.32515 + 6.28836e-05
# [300]	cv_agg's binary_logloss: 0.325107 + 6.68549e-05
# [400]	cv_agg's binary_logloss: 0.3251 + 7.17746e-05
# [500]	cv_agg's binary_logloss: 0.325092 + 8.03561e-05
# [600]	cv_agg's binary_logloss: 0.325081 + 7.35863e-05
# [700]	cv_agg's binary_logloss: 0.325082 + 7.25893e-05
# [800]	cv_agg's binary_logloss: 0.325081 + 7.02063e-05
# Feature  193
# [100]	cv_agg's binary_logloss: 0.326006 + 3.25919e-05
# [200]	cv_agg's binary_logloss: 0.325973 + 6.13782e-05
# [300]	cv_agg's binary_logloss: 0.325978 + 7.36714e-05
# Feature  194
# [100]	cv_agg's binary_logloss: 0.325892 + 3.0596e-05
# [200]	cv_agg's binary_logloss: 0.325827 + 3.93553e-05
# [300]	cv_agg's binary_logloss: 0.32581 + 4.51833e-05
# [400]	cv_agg's binary_logloss: 0.325814 + 5.70833e-05
# Feature  195
# [100]	cv_agg's binary_logloss: 0.325718 + 1.40441e-05
# [200]	cv_agg's binary_logloss: 0.325616 + 2.84832e-05
# [300]	cv_agg's binary_logloss: 0.325597 + 4.61887e-05
# [400]	cv_agg's binary_logloss: 0.325607 + 5.69647e-05
# Feature  196
# [100]	cv_agg's binary_logloss: 0.325837 + 4.09819e-05
# [200]	cv_agg's binary_logloss: 0.325751 + 5.17979e-05
# [300]	cv_agg's binary_logloss: 0.325731 + 5.19204e-05
# [400]	cv_agg's binary_logloss: 0.32573 + 5.2751e-05
# [500]	cv_agg's binary_logloss: 0.325727 + 4.36144e-05
# [600]	cv_agg's binary_logloss: 0.325725 + 4.18676e-05
# [700]	cv_agg's binary_logloss: 0.325724 + 3.63784e-05
# [800]	cv_agg's binary_logloss: 0.325724 + 3.17314e-05
# Feature  197
# [100]	cv_agg's binary_logloss: 0.325503 + 5.27393e-05
# [200]	cv_agg's binary_logloss: 0.325346 + 9.83435e-05
# [300]	cv_agg's binary_logloss: 0.325304 + 0.000124049
# [400]	cv_agg's binary_logloss: 0.3253 + 0.000141478
# [500]	cv_agg's binary_logloss: 0.325303 + 0.000150158
# Feature  198
# [100]	cv_agg's binary_logloss: 0.324593 + 5.7181e-05
# [200]	cv_agg's binary_logloss: 0.324234 + 0.00011947
# [300]	cv_agg's binary_logloss: 0.32413 + 0.000155824
# [400]	cv_agg's binary_logloss: 0.324114 + 0.000170881
# [500]	cv_agg's binary_logloss: 0.32411 + 0.000175542
# [600]	cv_agg's binary_logloss: 0.324106 + 0.000175242
# Feature  199
# [100]	cv_agg's binary_logloss: 0.325878 + 4.836e-05
# [200]	cv_agg's binary_logloss: 0.325794 + 6.01435e-05
# [300]	cv_agg's binary_logloss: 0.325774 + 6.63501e-05
# [400]	cv_agg's binary_logloss: 0.325764 + 7.21002e-05
# [500]	cv_agg's binary_logloss: 0.325755 + 6.77648e-05
# [600]	cv_agg's binary_logloss: 0.325752 + 6.12939e-05

# %%
num_ones = np.sum(target.iloc[:, 0] == 1)
num_zeros = np.sum(target.iloc[:, 0] == 0)

class LGBNaiveBayes:
    def fit(self,df_train, target, opt_rounds):
        self.clfs = []
        for i in range(len(df_train.columns)):
            if i%20 == 0:
                print("Fitting var_"+ str(i)+"...")
            params['n_estimators'] = opt_rounds[i]

            lgb_clf = lgb.LGBMClassifier(**params)
            lgb_clf.fit(df_train[['var_'+str(i)]], target)

            self.clfs.append(lgb_clf)
            
    def predict_proba(self,df_train):
        log_sum = np.zeros((df_train.shape[0],2))
        for i in range(len(df_train.columns)):

            log_sum += np.log(self.clfs[i].predict_proba(df_train[['var_'+str(i)]]))
            log_sum += np.array([np.log(num_ones) - np.log(200000), np.log(num_zeros) - np.log(200000)])
            
        log_sum -= np.array([np.log(num_ones) - np.log(200000), np.log(num_zeros) - np.log(200000)])
        
        log_prob_x = logsumexp(log_sum, axis=1)
        return np.exp(log_sum - np.atleast_2d(log_prob_x).T)
clf = LGBNaiveBayes()

# %%
clf = LGBNaiveBayes()

def cross_validate(nfolds):
    sss = StratifiedShuffleSplit(nfolds)
    aucs = []
    for train, test in sss.split(origin_train[features], origin_train['target']):
        clf.fit(origin_train.loc[train][features], origin_train.loc[train]['target'], opt_rounds)
        y_true = origin_train.loc[test]['target']
        y_pred = clf.predict_proba(origin_train.loc[test][features])[:,1]
        test_auc = roc_auc_score(y_true, y_pred)
        aucs.append(test_auc)
        print("Test AUC:", test_auc)
    print("Mean test AUC: ", np.mean(aucs))
    
cross_validate(5)
# Out:
# Fitting var_0...
# Fitting var_20...
# Fitting var_40...
# Fitting var_60...
# Fitting var_80...
# Fitting var_100...
# Fitting var_120...
# Fitting var_140...
# Fitting var_160...
# Fitting var_180...
# Test AUC: 0.9024156316803973
# Fitting var_0...
# Fitting var_20...
# Fitting var_40...
# Fitting var_60...
# Fitting var_80...
# Fitting var_100...
# Fitting var_120...
# Fitting var_140...
# Fitting var_160...
# Fitting var_180...
# Test AUC: 0.9030722706644653
# Fitting var_0...
# Fitting var_20...
# Fitting var_40...
# Fitting var_60...
# Fitting var_80...
# Fitting var_100...
# Fitting var_120...
# Fitting var_140...
# Fitting var_160...
# Fitting var_180...
# Test AUC: 0.9012663198736722
# Fitting var_0...
# Fitting var_20...
# Fitting var_40...
# Fitting var_60...
# Fitting var_80...
# Fitting var_100...
# Fitting var_120...
# Fitting var_140...
# Fitting var_160...
# Fitting var_180...
# Test AUC: 0.901244140608796
# Fitting var_0...
# Fitting var_20...
# Fitting var_40...
# Fitting var_60...
# Fitting var_80...
# Fitting var_100...
# Fitting var_120...
# Fitting var_140...
# Fitting var_160...
# Fitting var_180...
# Test AUC: 0.9084616107898529
# Mean test AUC:  0.9032919947234367

# %%
clf.fit(origin_train[features], origin_train['target'], opt_rounds)
pred = clf.predict_proba(origin_test.iloc[:][features])
sub_df = pd.DataFrame({"ID_code":origin_test["ID_code"].values})
sub_df["target"] = pred[:,1]
sub_df.to_csv("naive_bayes_submission.csv", index=False)
# Out:
# Fitting var_0...
# Fitting var_20...
# Fitting var_40...
# Fitting var_60...
# Fitting var_80...
# Fitting var_100...
# Fitting var_120...
# Fitting var_140...
# Fitting var_160...
# Fitting var_180...
